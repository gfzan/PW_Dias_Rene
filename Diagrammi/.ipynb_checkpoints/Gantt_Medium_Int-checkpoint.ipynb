# %% [markdown]
# ## Gantt charts with Python’s Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#%matplotlib

df = pd.read_excel('XLS/PLAN_Int.xlsx')

# %% [raw]
# #df['Task'] = df['Task'].astype(str)
# #df.Task.to_string()
# df.Task

# %%
df['Task'] = df['Task'].astype(str)
#df.dtypes
proj_start = df.Start.min()       # number of days from project start to task start
df['start_num'] = (df.Start-proj_start)    # number of days from project start to end of tasks
df['end_num'] = (df.Lenght+df.start_num)       # days between start and end of each task
df['months_start_to_end'] = df.end_num - df.start_num

colorPalette = ['#B8860B', '#CD853F', '#D2691E', '#808000', '#8B4513', '#A0522D',
                '#6495ED', '#00BFFF', '#1E90FF', '#4169E1', '#0000FF', '#0000CD', '#00008B', '#000080', '#191970', 
                '#E9967A', '#F08080', '#CD5C5C', '#DC143C', '#FF0000', '#B22222',
                '#A9A9A9', '#696969', '#808080', '#778899', '#708090', '#2F4F4F']
c_dict = dict(zip(df['Task'].to_list(), colorPalette))
legend = dict(zip(df.Attività.to_list(), colorPalette ))

def color(row):
    #c_dict = dict(zip(jobDesc, colorPalette))
    return c_dict[row['Task']]
df['color'] = df.apply(color, axis=1)

# months between start and current progression of each task
df['current_num'] = (df.months_start_to_end * df.Completion)
df
# Out:
#    Task                                           Attività  Start  Lenght  \
# 0   1.1  1.1 organizzazione e gestione delle riunioni d...      1       2
# 1   1.2                1.2 verifiche qualità ed indicatori      3      34
# 2   1.3   1.3 perfezionamento convenzioni con  istituzioni      1      36
# 3   1.4  1.4 approvazione comitato etico per spin off d...      1       8
# 4   1.5  1.5 promozione del progetto: istituzioni, oper...      5      32
# 5   1.6  1.6 gruppo di lavoro con società scientifiche ...     13      24
# 6   2.1  2.1 procedura di gara: redazione capitolato, d...      1       5
# 7   2.2              2-2 strutturazione formale della rete      1       3
# 8   2.3            2.3 ottimizzazione piattaforma digitale      2       5
# 9   2.4               2.4 ottimizzazione software spectrum      1       6
# 10  2.5                2.5 formazione operatori centro hub      6       1
# 11  2.6             2.6 formazione operatori centri spokes      1       6
# 12  2.7  2.7 sviluppo di nuovi protocolli analitici da ...      1       3
# 13  2.8  2.8 inquadramento legislativo e amministrativo...      1       1
# 14  2.9  2.9 arruolamento pazienti con gestione tradizi...      1       6
# 15  3.1       3.1 arruolamento pazienti, digital pathology      7      30
# 16  3.2  3.2 implementazione dello studio di diagnostic...      7      30
# 17  3.3    3.3 training algoritmo intelligenza artificiale      7      15
# 18  3.4  3.4 validation algoritmo intelligenza artificiale     16      14
# 19  3.5  3.5 integrazione clinico-patologica per stress...     30       7
# 20  4.1  4.1 pubblicazione del risultati raggiunti nell...     31       6
# 21  4.2  4.2 conclusione e outlook sulle implementazion...     34       3
#
#     Completion  start_num  end_num  months_start_to_end    color  current_num
# 0            3          0        2                    2  #B8860B            6
# 1           37          2       36                   34  #CD853F         1258
# 2           37          0       36                   36  #D2691E         1332
# 3            9          0        8                    8  #808000           72
# 4           37          4       36                   32  #8B4513         1184
# 5           37         12       36                   24  #A0522D          888
# 6            6          0        5                    5  #6495ED           30
# 7            4          0        3                    3  #00BFFF           12
# 8            7          1        6                    5  #1E90FF           35
# 9            7          0        6                    6  #4169E1           42
# 10           7          5        6                    1  #0000FF            7
# 11           7          0        6                    6  #0000CD           42
# 12           4          0        3                    3  #00008B           12
# 13           2          0        1                    1  #000080            2
# 14           7          0        6                    6  #191970           42
# 15          37          6       36                   30  #E9967A         1110
# 16          37          6       36                   30  #F08080         1110
# 17          22          6       21                   15  #CD5C5C          330
# 18          30         15       29                   14  #DC143C          420
# 19          37         29       36                    7  #FF0000          259
# 20          37         30       36                    6  #B22222          222
# 21          37         33       36                    3  #A9A9A9          111

# %%
from matplotlib.patches import Patch

plt.style.use('seaborn')

##### LEGENDS #####
legend_dict = dict(zip(df.Attività.to_list(), colorPalette ))
legend_elements = [Patch(facecolor=legend_dict[i], label=i)  for i in legend_dict]

#plt.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, 0.5))

##### TICKS #####
#xticks = np.arange(-0, df.end_num.max()+1, 2)
xticks = np.arange(-0, 38, 1)
#xticks_labels = pd.interval_range(proj_start, end=df.Lenght.max())      ## modifica per interi
#xticks_labels = pd.interval_range(proj_start, end=38) 
xticks_minor = np.arange(0, 38, 1)

# %% [markdown]
# ## MULTIPLE PLOT GANTT CHART

# %% [raw]
# gs_kw = dict(height_ratios=[6, 9, 6, 2], wspace=0.4, hspace=1.5)
# sizeTxtLabel= 11
# plt.style.use('seaborn-whitegrid')
# fig, ax = plt.subplots(4, figsize=(16,20), gridspec_kw=gs_kw, sharex=False)
# #ax = ax.ravel()
#
# fig.suptitle('Gantt Chart: PW Dias Kidney', color='#000000', size=18)
#
# df0 = df[df['Task'] <'2']
# df0 = df0.iloc[::-1].reset_index(drop=True)
# ax[0].barh(df0.Task, df0.months_start_to_end, left=df0.start_num, color=df0.color, alpha=0.5)
# ax[0].set_title('Attività 1 : Project Management', pad=25)
#
# for idx, row in df0.iterrows():
#     if row.Lenght<13 and row.start_num>25:
#         ax[0].text(row.start_num-len(row.Attività)/6-2, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     elif row.Lenght<13 and row.start_num<20:
#         ax[0].text(row.end_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     else:
#         ax[0].text(row.start_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#
# df1 = df[(df.Task > '2') & (df.Task<'3')]
# df1 = df1.iloc[::-1].reset_index(drop=True)
# ax[1].barh(df1.Task, df1.months_start_to_end, left=df1.start_num, color=df1.color, alpha=0.5)
# ax[1].set_title('Attività 2 : fase avvio ', pad=25)
#
# for idx, row in df1.iterrows():
#     if row.Lenght<13 and row.start_num>25:
#         ax[1].text(row.start_num-len(row.Attività)/6-2, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     elif row.Lenght<13 and row.start_num<20:
#         ax[1].text(row.end_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     else:
#         ax[1].text(row.start_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#
# df2 = df[(df.Task > '3') & (df.Task<'4')]
# df2 = df2.iloc[::-1].reset_index(drop=True)
# ax[2].barh(df2.Task, df2.months_start_to_end, left=df2.start_num, color=df2.color, alpha=0.5)
# ax[2].set_title('Attività 3 : fase esecutiva', pad=25)
#
# for idx, row in df2.iterrows():
#     if row.Lenght<13 and row.start_num>25:
#         ax[2].text(row.start_num-len(row.Attività)/6-2, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     elif row.Lenght<13 and row.start_num<20:
#         ax[2].text(row.end_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     else:
#         ax[2].text(row.start_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#
# df3 = df[(df.Task > '4')]
# df3 = df3.iloc[::-1].reset_index(drop=True)
# ax[3].barh(df3.Task, df3.months_start_to_end, left=df3.start_num, color=df3.color, alpha=0.5)
# ax[3].set_title('Attività 4 : fase conclusiva', pad=25)
#
# for idx, row in df3.iterrows():
#     if row.Lenght<13 and row.start_num>25:
#         ax[3].text(row.start_num-(len(row.Attività)/6)-2, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     elif row.Lenght<13 and row.start_num<20:
#         ax[3].text(row.end_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#     else:
#         ax[3].text(row.start_num+0.6, idx, f"{row.Attività}", color='#000000', va='center', alpha=0.8, size=sizeTxtLabel)
#
#
# for i in range(4):
#     ax[i].set_xticks(xticks)
#     #ax[i].set_xticks(xticks_minor, minor=True)
#
#     #aggiunta
#     #ax[i].yaxis.set_visible(False)
#     #ax[i].set_facecolor('#006666')
#
#     #ax.axis('off')
#     ax[i].spines[["top", "right", 'left']].set_visible(False)
#
#     ax[i].set_xlabel('DURATA (mesi)',color='#000000')
#     ax[i].set(xlim=[0, 36])
#
#
# #fig.set_facecolor('#006666')
# plt.show()
# #plt.savefig("IMG/Gantt_PW_Dias_MultiPlot.png", bbox_inches="tight", dpi=600)

# %% [markdown]
# ## MULTIPLE PLOT GANTT CHART

# %%
gs_kw = dict(height_ratios=[6, 9, 6, 2], wspace=0.4, hspace=2)
sizeTxtLabel= 11
plt.style.use('seaborn-whitegrid')
fig, ax = plt.subplots(4, figsize=(16,25), gridspec_kw=gs_kw, sharex=False)
#ax = ax.ravel()
posY = 1.5

fig.suptitle('Gantt Chart: PW Dias Kidney', color='#000000', size=18)

df0 = df[df['Task'] <'2']
df0 = df0.iloc[::-1].reset_index(drop=True)
ax[0].barh(df0.Task, df0.months_start_to_end, left=df0.start_num, color=df0.color, alpha=0.5)
ax[0].set_title('Attività 1 : Project Management', pad=25, size=14, fontweight='bold')
##### LEGENDS #####
legend_dict = dict(zip(df0.Attività.to_list(), df0.color))
legend_elements = [Patch(facecolor=legend_dict[i], label=i)  for i in legend_dict]
ax[0].legend(handles=legend_elements[::-1], loc='upper left', bbox_to_anchor=(0.2,-posY/6))


        
df1 = df[(df.Task > '2') & (df.Task<'3')]
df1 = df1.iloc[::-1].reset_index(drop=True)
ax[1].barh(df1.Task, df1.months_start_to_end, left=df1.start_num, color=df1.color, alpha=0.5, label=df1.Attività)
ax[1].set_title('Attività 2 : fase avvio ', pad=25, size=14, fontweight='bold')
##### LEGENDS #####
legend_dict = dict(zip(df1.Attività.to_list(), df1.color))
legend_elements = [Patch(facecolor=legend_dict[i], label=i)  for i in legend_dict]
ax[1].legend(handles=legend_elements[::-1], loc='upper left', bbox_to_anchor=(0.2,-posY/9))

            
df2 = df[(df.Task > '3') & (df.Task<'4')]
df2 = df2.iloc[::-1].reset_index(drop=True)
ax[2].barh(df2.Task, df2.months_start_to_end, left=df2.start_num, color=df2.color, alpha=0.5, label=df2.Attività)
ax[2].set_title('Attività 3 : fase esecutiva', pad=25, size=14, fontweight='bold')
##### LEGENDS #####
legend_dict = dict(zip(df2.Attività.to_list(), df2.color))
legend_elements = [Patch(facecolor=legend_dict[i], label=i)  for i in legend_dict]
ax[2].legend(handles=legend_elements[::-1], loc='upper left', bbox_to_anchor=(0.2,-posY/6))
       
df3 = df[(df.Task > '4')]
df3 = df3.iloc[::-1].reset_index(drop=True)
ax[3].barh(df3.Task, df3.months_start_to_end, left=df3.start_num, color=df3.color, alpha=0.5, label=df3.Attività)
ax[3].set_title('Attività 4 : fase conclusiva', pad=25, size=14, fontweight='bold')
##### LEGENDS #####
legend_dict = dict(zip(df3.Attività.to_list(), df3.color))
legend_elements = [Patch(facecolor=legend_dict[i], label=i)  for i in legend_dict]
ax[3].legend(handles=legend_elements[::-1], loc='upper left', bbox_to_anchor=(0.2,-posY/2))

for ax in ax:
    #ax.legend(handles=legend_elements[ax][::-1], loc='upper center', bbox_to_anchor=(0.4,-1))
    
    ax.set_xticks(xticks)
    #ax.spines[["top", "right", 'left']].set_visible(False)

    ax.set_xlabel('DURATA (mesi)',color='#000000')
    ax.set(xlim=[0, 36])

#fig.set_facecolor('#006666')
plt.show()
plt.savefig("IMG/Gantt_PW_Dias_MultiPlot.png", bbox_inches="tight", dpi=600)
